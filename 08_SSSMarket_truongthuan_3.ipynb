# %% [markdown]
# <a href="https://colab.research.google.com/github/truongthuanr/transfer/blob/main/08_SSSMarket_truongthuan_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from collections import Counter
import seaborn as sns

from random import randint
from urllib.request import urlopen

from numpy import asarray

# %%
train_url = "https://raw.githubusercontent.com/truongthuanr/self-project/main/dataset/sss/train.csv"
df = pd.read_csv(train_url)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4705 entries, 0 to 4704
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    4705 non-null   int64
#  1   sku                   4705 non-null   int64
#  2   short_description     4640 non-null   object
#  3   price                 4705 non-null   int64
#  4   discount              4705 non-null   int64
#  5   discount_rate         4705 non-null   int64
#  6   rating_average        4705 non-null   float64
#  7   review_count          4705 non-null   int64
#  8   order_count           4705 non-null   int64
#  9   favourite_count       4705 non-null   int64
#  10  thumbnail_url         4705 non-null   object
#  11  categories            4705 non-null   object
#  12  liked                 4705 non-null   bool
#  13  rating_summary        4705 non-null   object
#  14  brand                 4705 non-null   object
#  15  current_seller        4653 non-null   object
#  16  other_sellers         4705 non-null   object
#  17  configurable_options  4042 non-null   object
#  18  extra_feature         4705 non-null   object
#  19  cloth_type            4427 non-null   object
# dtypes: bool(1), float64(1), int64(8), object(10)
# memory usage: 703.1+ KB

# %%
df.head(3)
# Out:
#    id            sku  ... extra_feature                         cloth_type
# 0   0  4777164499549  ...            []  top_t-shirt_sweatshirt shoe pants
# 1   1  2931572867679  ...            []                            sweater
# 2   2  6427102533481  ...            []      watch shoe shirt_blouse pants
#
# [3 rows x 20 columns]

# %% [markdown]
# # Exploratory Data Analysis

# %%
from random import randint
from urllib.request import urlopen

# %%
total_images = df.thumbnail_url.notna().sum()
total_images
# Out:
# 4705

# %%
# plot random 12 image
fig = plt.figure(figsize=(20,10))
for i in range(0,12):
  ax = plt.subplot(3,4,i+1)
  _i = randint(0,total_images)
  img = Image.open(urlopen(df.thumbnail_url[_i]))
  ax = plt.imshow(img)
  plt.title(f"{_i} - {df.cloth_type[_i]}")
  plt.axis("off")

# %% [markdown]
# ## Check for label

# %%
# create a list of list of labels 
labels = df.cloth_type.str.split(" ").tolist()
labels = [item if type(item) == list else [str(item)] for item in labels]
labels[:5]
# Out:
# [['top_t-shirt_sweatshirt', 'shoe', 'pants'],
#  ['sweater'],
#  ['watch', 'shoe', 'shirt_blouse', 'pants'],
#  ['belt', 'dress', 'bag_wallet', 'shoe'],
#  ['bag_wallet', 'dress', 'shoe']]

# %%
# Count the apperence of label
all_label = [label for sub in labels for label in sub]
labels_count = Counter(all_label)
labels_count
# Out:
# Counter({'': 10,
#          'bag_wallet': 438,
#          'belt': 410,
#          'cardigan': 31,
#          'coat': 152,
#          'dress': 768,
#          'glasses': 119,
#          'hat': 195,
#          'headband_head-covering_hair-accessory': 99,
#          'jacket': 414,
#          'jumpsuit': 25,
#          'nan': 278,
#          'pants': 1616,
#          'scarf': 5,
#          'shirt_blouse': 480,
#          'shoe': 1520,
#          'shorts': 479,
#          'skirt': 750,
#          'sweater': 116,
#          'top_t-shirt_sweatshirt': 2382,
#          'vest': 4,
#          'watch': 463})

# %% [markdown]
# Why is label `''`???
#
# Let's check the no label images!!

# %%
index = []
for i in range(len(labels)):
  valid = True
  for label in labels[i]:
    if label == '': valid = False
  if valid == False: index.append(i)

index
# Out:
# [2233, 3586, 4205, 4560, 4628]

# %%
df[df.cloth_type==" "].index
# Out:
# Int64Index([2233, 3586, 4205, 4560, 4628], dtype='int64')

# %%
# plot the invalid images
fig = plt.figure(figsize=(20,10))
for i in range(len(index)):
  ax = plt.subplot(1,5,i+1)
  img = Image.open(urlopen(df.thumbnail_url[index[i]]))
  ax = plt.imshow(img)
  plt.title(f"{index[i]} - {df.cloth_type[index[i]]} no label")
  plt.axis("off")

# %% [markdown]
# Check the n/a label images

# %%
df_na = df[df['cloth_type'].isna()==True].copy()
df_na.reset_index(inplace=True, drop=True)

# %%
# plot random 24 image
fig = plt.figure(figsize=(20,10))
for i in range(0,24):
  ax = plt.subplot(4,6,i+1)
  _i = randint(0,len(df_na))
  img = Image.open(urlopen(df_na.thumbnail_url[_i]))
  ax = plt.imshow(img)
  plt.title(f"{_i} - {df_na.cloth_type[_i]}")
  plt.axis("off")

# %%
df.cloth_type.isna().sum()
# Out:
# 278

# %% [markdown]
# ## Remove na label

# %%
df.drop(labels=df[df.cloth_type==" "].index, inplace=True)
df.drop(labels=df[df.cloth_type.isna()==True].index, inplace=True)
df.reset_index(drop=True, inplace=True)
len(df)
# Out:
# 4422

# %%
total_images = df.thumbnail_url.notna().sum()
total_images
# Out:
# 4422

# %%
# create a list of list of labels 
labels = df.cloth_type.str.split(" ").tolist()
labels = [item if type(item) == list else [str(item)] for item in labels]
labels[:5]
# Out:
# [['top_t-shirt_sweatshirt', 'shoe', 'pants'],
#  ['sweater'],
#  ['watch', 'shoe', 'shirt_blouse', 'pants'],
#  ['belt', 'dress', 'bag_wallet', 'shoe'],
#  ['bag_wallet', 'dress', 'shoe']]

# %%
# Count the apperence of label
all_label = [label for sub in labels for label in sub]
labels_count = Counter(all_label)
labels_count
# Out:
# Counter({'bag_wallet': 438,
#          'belt': 410,
#          'cardigan': 31,
#          'coat': 152,
#          'dress': 768,
#          'glasses': 119,
#          'hat': 195,
#          'headband_head-covering_hair-accessory': 99,
#          'jacket': 414,
#          'jumpsuit': 25,
#          'pants': 1616,
#          'scarf': 5,
#          'shirt_blouse': 480,
#          'shoe': 1520,
#          'shorts': 479,
#          'skirt': 750,
#          'sweater': 116,
#          'top_t-shirt_sweatshirt': 2382,
#          'vest': 4,
#          'watch': 463})

# %%
# 1430

# %% [markdown]
# Create Mapping

# %%
labels_count = Counter(all_label)
# sort by frequency
label_name = [tag for tag,count in labels_count.most_common()]
label_freq = [count for tag,count in labels_count.most_common()]

# %%
label_map = {label_name[i]: i for i in range(0,len(label_name))}
inv_label_map = {i:label_name[i] for i in range(0,len(label_name))}

# %% [markdown]
# Whichs are the tops used label?

# %%
fig = plt.figure(figsize=(10,5))
plt.bar(label_name, label_freq, color="#99C8BC")
plt.title("Label in data")
plt.xticks(rotation=90)
for i, (tag,count) in enumerate(labels_count.most_common()):
  plt.text(i, count, f" {count} ", rotation=90, ha="center", va="bottom", color="black")
plt.ylim(0,3000);

# %% [markdown]
# Create a one hot encoding for one list of tags

# %%
from numpy import asarray

# %%
def one_hot_encoder(tags, mapping):
  # create empty vector
  encoding = np.zeros(len(label_map), dtype="uint")
  # mark 1 for each tag in the vector
  for tag in tags:
    encoding[label_map[tag]] = 1
  return encoding

# %%
def load_dataset(images_url, labels, label_map):
  # images,  targets = list(), list()
  images = []
  targets = []
  for i in range(0,len(images_url)):
    # load_img
    img = Image.open(urlopen(images_url[i]))
    if img.mode != 'RGB': img = img.convert('RGB')

    # turn image in to array
    img = asarray(img)
    tags = labels[i]
    target = one_hot_encoder(tags, label_map)

    images.append(img)
    targets.append(target)

  X = asarray(images, dtype="uint8")
  y = asarray(targets, dtype="uint8")

  return X, y

# %%
import tensorflow as tf
device_name = tf.test.gpu_device_name()
device_name
# Out:
# '/device:GPU:0'

# %%
X, y = load_dataset(df.thumbnail_url, labels, label_map)

# %% [markdown]
# save the array:

# %%
np.savez_compressed("/content/drive/MyDrive/01_AI_ML/sss/sss_data_full_dropnalabel.npz", X, y)

# %%
X.shape
# Out:
# (4422, 280, 280, 3)

# %% [markdown]
# load array:

# %%
data = np.load("/content/drive/MyDrive/01_AI_ML/sss/sss_data_full_dropnalabel.npz")
X, y = data["arr_0"], data["arr_1"]
print(f"Loaded: {X.shape} {y.shape}")
# Out:
# Loaded: (4422, 280, 280, 3) (4422, 20)

# %% [markdown]
# # How to evaluate model

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=99)

# %%
train_yhat = asarray([np.ones(y_train.shape[1]) for _ in range(y_train.shape[0])])

# %%
from sklearn.metrics import fbeta_score
from sklearn.metrics import f1_score

# %%
fbeta_score(y_train, train_yhat, beta=2, average='samples')
# Out:
# 0.3762009229704199

# %%
f1_score(y_train, train_yhat, average='samples')
# Out:
# 0.2050400725238526

# %%
X_train.shape
# Out:
# (2962, 280, 280, 3)

# %% [markdown]
# # Baseline model

# %%
import sys
from keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout
from tensorflow.keras.optimizers import SGD
from keras.preprocessing.image import ImageDataGenerator
from keras import backend

# %%
def fbeta(y_true, y_pred, beta=1):
  # clip prediction
  y_pred = backend.clip(y_pred,0,1)
  # calculate elements
  tp = backend.sum(backend.round(backend.clip(y_true * y_pred, 0, 1)), axis=1)
  fp = backend.sum(backend.round(backend.clip(y_pred - y_true, 0, 1)), axis=1)
  fn = backend.sum(backend.round(backend.clip(y_true - y_pred, 0, 1)), axis=1)
  # calculate precision
  p = tp / (tp + fp + backend.epsilon())
  # calculate recall
  r = tp / (tp + fn + backend.epsilon())
  # calculate fbeta
  bb = beta**2
  fbeta_score = backend.mean((1+bb)*(p*r)/(bb*p+r+backend.epsilon()))
  return fbeta_score

# %%
fbeta(y_train, train_yhat, beta=2)
# Out:
# <tf.Tensor: shape=(), dtype=float64, numpy=0.3762008920953505>

# %%
# def define_model(in_shape=(280,280,3), out_shape=22):
#   model = Sequential()
#   model.add(Conv2D(32,
#                    (3,3), 
#                    activation="relu", 
#                    kernel_initializer='he_uniform',
#                    padding="same",
#                    input_shape=in_shape
#                    )
#   )
#   model.add(Conv2D(32,
#                    (3,3), 
#                    activation="relu", 
#                    kernel_initializer='he_uniform',
#                    padding="same",
#                    input_shape=in_shape
#                    )
#   )
#   model.add(MaxPool2D((2, 2)))
#   model.add(Conv2D(64,
#                    (3,3), 
#                    activation="relu", 
#                    kernel_initializer='he_uniform',
#                    padding="same",
#                    input_shape=in_shape
#                    )
#   )
#   model.add(Conv2D(64,
#                    (3,3), 
#                    activation="relu", 
#                    kernel_initializer='he_uniform',
#                    padding="same",
#                    input_shape=in_shape
#                    )
#   )
#   model.add(MaxPool2D((2, 2)))
#   model.add(Conv2D(128,
#                    (3,3), 
#                    activation="relu", 
#                    kernel_initializer='he_uniform',
#                    padding="same",
#                    input_shape=in_shape
#                    )
#   )
#   model.add(Conv2D(128,
#                    (3,3), 
#                    activation="relu", 
#                    kernel_initializer='he_uniform',
#                    padding="same",
#                    input_shape=in_shape
#                    )
#   )
#   model.add(MaxPool2D((2, 2)))
#   model.add(Flatten())
#   model.add(Dense(128, activation="relu", kernel_initializer='he_uniform'))
#   model.add(Dense(out_shape, activation="sigmoid"))

#   # Compile model
#   opt = SGD(learning_rate=0.01, momentum=0.9)
#   model.compile(optimizer=opt, loss='binary_crossentropy', metrics=[fbeta])

#   return model

# %% [markdown]
# Baseline with `drop out` to prevent overfitting

# %%
def define_model(in_shape=(280,280,3), out_shape=20):
  model = Sequential()
  model.add(Conv2D(32,
                   (3,3), 
                   activation="relu", 
                   kernel_initializer='he_uniform',
                   padding="same",
                   input_shape=in_shape
                   )
  )
  model.add(Conv2D(32,
                   (3,3), 
                   activation="relu", 
                   kernel_initializer='he_uniform',
                   padding="same",
                   input_shape=in_shape
                   )
  )
  model.add(MaxPool2D((2, 2)))
  model.add(Dropout(0.2))
  model.add(Conv2D(64,
                   (3,3), 
                   activation="relu", 
                   kernel_initializer='he_uniform',
                   padding="same",
                   input_shape=in_shape
                   )
  )
  model.add(Conv2D(64,
                   (3,3), 
                   activation="relu", 
                   kernel_initializer='he_uniform',
                   padding="same",
                   input_shape=in_shape
                   )
  )
  model.add(MaxPool2D((2, 2)))
  model.add(Dropout(0.2))
  model.add(Conv2D(128,
                   (3,3), 
                   activation="relu", 
                   kernel_initializer='he_uniform',
                   padding="same",
                   input_shape=in_shape
                   )
  )
  model.add(Conv2D(128,
                   (3,3), 
                   activation="relu", 
                   kernel_initializer='he_uniform',
                   padding="same",
                   input_shape=in_shape
                   )
  )
  model.add(MaxPool2D((2, 2)))
  model.add(Dropout(0.2))
  model.add(Flatten())
  model.add(Dense(128, activation="relu", kernel_initializer='he_uniform'))
  model.add(Dropout(0.5))
  model.add(Dense(out_shape, activation="sigmoid"))

  # Compile model
  opt = SGD(learning_rate=0.01, momentum=0.9)
  model.compile(optimizer=opt, loss='binary_crossentropy', metrics=[fbeta])

  return model

# %%
# plot diagnostic learning curves
def summarize_diagnostics(history):
  # plot loss
  plt.subplot(211)
  plt.title("Cross Entropy Loss")
  plt.plot(history.history["loss"], color='blue', label='train')
  plt.plot(history.history['val_loss'],color='orange', label='test')

  # plot accuracy
  plt.subplot(212)
  plt.title("F1 Score")
  plt.plot(history.history["fbeta"], color='blue', label='train')
  plt.plot(history.history['val_fbeta'],color='orange', label='test')

# %%
datagen = ImageDataGenerator(rescale=1.0/225.0)
train_it = datagen.flow(X_train, y_train, batch_size=128)
test_it = datagen.flow(X_test, y_test, batch_size=128)
model = define_model()

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 280, 280, 32)      896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 280, 280, 32)      9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 140, 140, 32)      0
# _________________________________________________________________
# dropout (Dropout)            (None, 140, 140, 32)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 140, 140, 64)      18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 140, 140, 64)      36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 70, 70, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 70, 70, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 70, 70, 128)       73856
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 70, 70, 128)       147584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 35, 35, 128)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 35, 35, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 156800)            0
# _________________________________________________________________
# dense (Dense)                (None, 128)               20070528
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 20)                2580
# =================================================================
# Total params: 20,360,116
# Trainable params: 20,360,116
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(train_it, 
                    steps_per_epoch=len(train_it), 
                    validation_data=test_it, 
                    validation_steps=len(test_it),
                    epochs=50)
# Out:
# Epoch 1/50
# 24/24 [==============================] - 94s 2s/step - loss: 0.5332 - fbeta: 0.2688 - val_loss: 0.4077 - val_fbeta: 0.0000e+00
# Epoch 2/50
# 24/24 [==============================] - 38s 2s/step - loss: 0.3334 - fbeta: 0.2393 - val_loss: 0.4344 - val_fbeta: 0.3391
# Epoch 3/50
# 24/24 [==============================] - 38s 2s/step - loss: 0.3201 - fbeta: 0.2584 - val_loss: 0.4347 - val_fbeta: 0.3342
# Epoch 4/50
# 24/24 [==============================] - 38s 2s/step - loss: 0.3139 - fbeta: 0.2600 - val_loss: 0.4068 - val_fbeta: 0.3403
# Epoch 5/50
# 24/24 [==============================] - 38s 2s/step - loss: 0.3107 - fbeta: 0.2329 - val_loss: 0.4070 - val_fbeta: 0.3373
# Epoch 6/50
# 24/24 [==============================] - 38s 2s/step - loss: 0.3078 - fbeta: 0.2374 - val_loss: 0.4519 - val_fbeta: 0.3414
# Epoch 7/50
# 24/24 [==============================] - 38s 2s/step - loss: 0.3030 - fbeta: 0.2567 - val_loss: 0.3994 - val_fbeta: 0.3368
# Epoch 8/50
# 24/24 [==============================] - 38s 2s/step - loss: 0.2984 - fbeta: 0.2612 - val_loss: 0.3955 - val_fbeta: 0.3416
# Epoch 9/50
# 24/24 [==============================] - 38s 2s/step - loss: 0.2969 - fbeta: 0.2560 - val_loss: 0.4261 - val_fbeta: 0.3397
# Epoch 10/50
# 24/24 [==============================] - 38s 2s/step - loss: 0.2935 - fbeta: 0.2768 - val_loss: 0.4086 - val_fbeta: 0.3237
# Epoch 11/50
# 24/24 [==============================] - 38s 2s/step - loss: 0.2932 - fbeta: 0.2800 - val_loss: 0.4325 - val_fbeta: 0.2763
# Epoch 12/50
# 24/24 [==============================] - 38s 2s/step - loss: 0.2880 - fbeta: 0.3048 - val_loss: 0.3870 - val_fbeta: 0.3773
# Epoch 13/50
# 24/24 [==============================] - 38s 2s/step - loss: 0.2861 - fbeta: 0.3075 - val_loss: 0.4195 - val_fbeta: 0.3899
# Epoch 14/50
# 24/24 [==============================] - 38s 2s/step - loss: 0.2852 - fbeta: 0.3031 - val_loss: 0.3660 - val_fbeta: 0.3704
# Epoch 15/50
# 24/24 [==============================] - 38s 2s/step - loss: 0.2834 - fbeta: 0.3267 - val_loss: 0.3676 - val_fbeta: 0.3382
# Epoch 16/50
# 24/24 [==============================] - 38s 2s/step - loss: 0.2821 - fbeta: 0.3371 - val_loss: 0.3567 - val_fbeta: 0.3906
# Epoch 17/50
# 24/24 [==============================] - 38s 2s/step - loss: 0.2779 - fbeta: 0.3530 - val_loss: 0.3436 - val_fbeta: 0.3875
# Epoch 18/50
# 24/24 [==============================] - 38s 2s/step - loss: 0.2784 - fbeta: 0.3297 - val_loss: 0.3196 - val_fbeta: 0.4253
# Epoch 19/50
# 24/24 [==============================] - 38s 2s/step - loss: 0.2766 - fbeta: 0.3342 - val_loss: 0.3144 - val_fbeta: 0.3628
# Epoch 20/50
# 24/24 [==============================] - 38s 2s/step - loss: 0.2760 - fbeta: 0.3473 - val_loss: 0.3298 - val_fbeta: 0.2597
# Epoch 21/50
# 24/24 [==============================] - 38s 2s/step - loss: 0.2744 - fbeta: 0.3558 - val_loss: 0.3239 - val_fbeta: 0.3728
# Epoch 22/50
# 24/24 [==============================] - 38s 2s/step - loss: 0.2730 - fbeta: 0.3801 - val_loss: 0.3241 - val_fbeta: 0.4007
# Epoch 23/50
# 24/24 [==============================] - 38s 2s/step - loss: 0.2717 - fbeta: 0.3574 - val_loss: 0.3343 - val_fbeta: 0.3656
# Epoch 24/50
# 24/24 [==============================] - 38s 2s/step - loss: 0.2704 - fbeta: 0.3525 - val_loss: 0.3021 - val_fbeta: 0.3811
# Epoch 25/50
# 24/24 [==============================] - 38s 2s/step - loss: 0.2674 - fbeta: 0.3935 - val_loss: 0.3007 - val_fbeta: 0.3833
# Epoch 26/50
# 24/24 [==============================] - 38s 2s/step - loss: 0.2678 - fbeta: 0.3829 - val_loss: 0.3003 - val_fbeta: 0.4084
# Epoch 27/50
# 24/24 [==============================] - 38s 2s/step - loss: 0.2655 - fbeta: 0.3760 - val_loss: 0.3109 - val_fbeta: 0.3903
# Epoch 28/50
# 24/24 [==============================] - 38s 2s/step - loss: 0.2646 - fbeta: 0.3801 - val_loss: 0.3029 - val_fbeta: 0.4254
# Epoch 29/50
# 24/24 [==============================] - 38s 2s/step - loss: 0.2658 - fbeta: 0.3900 - val_loss: 0.3106 - val_fbeta: 0.3762
# Epoch 30/50
# 24/24 [==============================] - 38s 2s/step - loss: 0.2614 - fbeta: 0.4025 - val_loss: 0.2823 - val_fbeta: 0.4378
# Epoch 31/50
# 24/24 [==============================] - 38s 2s/step - loss: 0.2606 - fbeta: 0.3932 - val_loss: 0.2896 - val_fbeta: 0.4185
# Epoch 32/50
# 24/24 [==============================] - 38s 2s/step - loss: 0.2598 - fbeta: 0.4130 - val_loss: 0.2889 - val_fbeta: 0.4378
# Epoch 33/50
# 24/24 [==============================] - 38s 2s/step - loss: 0.2587 - fbeta: 0.4010 - val_loss: 0.2816 - val_fbeta: 0.4435
# Epoch 34/50
# 24/24 [==============================] - 38s 2s/step - loss: 0.2570 - fbeta: 0.4083 - val_loss: 0.3076 - val_fbeta: 0.4074
# Epoch 35/50
# 24/24 [==============================] - 38s 2s/step - loss: 0.2547 - fbeta: 0.4174 - val_loss: 0.3192 - val_fbeta: 0.3960
# Epoch 36/50
# 24/24 [==============================] - 38s 2s/step - loss: 0.2538 - fbeta: 0.4068 - val_loss: 0.3196 - val_fbeta: 0.3861
# Epoch 37/50
# 24/24 [==============================] - 38s 2s/step - loss: 0.2535 - fbeta: 0.4215 - val_loss: 0.2937 - val_fbeta: 0.4001
# Epoch 38/50
# 24/24 [==============================] - 38s 2s/step - loss: 0.2499 - fbeta: 0.4269 - val_loss: 0.2781 - val_fbeta: 0.4176
# Epoch 39/50
# 24/24 [==============================] - 38s 2s/step - loss: 0.2519 - fbeta: 0.4204 - val_loss: 0.2837 - val_fbeta: 0.4446
# Epoch 40/50
# 24/24 [==============================] - 38s 2s/step - loss: 0.2493 - fbeta: 0.4188 - val_loss: 0.2948 - val_fbeta: 0.4213
# Epoch 41/50
# 24/24 [==============================] - 38s 2s/step - loss: 0.2481 - fbeta: 0.4330 - val_loss: 0.2821 - val_fbeta: 0.4426
# Epoch 42/50
# 24/24 [==============================] - 38s 2s/step - loss: 0.2463 - fbeta: 0.4286 - val_loss: 0.2795 - val_fbeta: 0.4511
# Epoch 43/50
# 24/24 [==============================] - 38s 2s/step - loss: 0.2432 - fbeta: 0.4476 - val_loss: 0.2899 - val_fbeta: 0.4706
# Epoch 44/50
# 24/24 [==============================] - 38s 2s/step - loss: 0.2417 - fbeta: 0.4431 - val_loss: 0.2833 - val_fbeta: 0.4923
# Epoch 45/50
# 24/24 [==============================] - 38s 2s/step - loss: 0.2431 - fbeta: 0.4493 - val_loss: 0.3083 - val_fbeta: 0.4190
# Epoch 46/50
# 24/24 [==============================] - 38s 2s/step - loss: 0.2392 - fbeta: 0.4443 - val_loss: 0.2573 - val_fbeta: 0.4001
# Epoch 47/50
# 24/24 [==============================] - 38s 2s/step - loss: 0.2377 - fbeta: 0.4577 - val_loss: 0.2768 - val_fbeta: 0.4611
# Epoch 48/50
# 24/24 [==============================] - 38s 2s/step - loss: 0.2334 - fbeta: 0.4610 - val_loss: 0.2765 - val_fbeta: 0.4843
# Epoch 49/50
# 24/24 [==============================] - 38s 2s/step - loss: 0.2359 - fbeta: 0.4815 - val_loss: 0.2836 - val_fbeta: 0.4683
# Epoch 50/50
# 24/24 [==============================] - 38s 2s/step - loss: 0.2334 - fbeta: 0.4729 - val_loss: 0.2743 - val_fbeta: 0.4523

# %%
loss, fbeta = model.evaluate(test_it, steps=len(test_it))
# Out:
# 12/12 [==============================] - 5s 397ms/step - loss: 0.2743 - fbeta: 0.4570

# %%
print(f"> loss = {loss:.3f}, f1-mean = {fbeta:.3f}")
# Out:
# > loss = 0.274, f1-mean = 0.457

# %%
summarize_diagnostics(history)

# %%
model.save_weights('/content/drive/MyDrive/01_AI_ML/sss/model_dropna_dropout/model_dropna_dropout')

# %%
model.load_weights('/content/drive/MyDrive/01_AI_ML/sss/model_dropna_dropout/model_dropna_dropout')

# %% [markdown]
# # Prediction

# %%
train_url = "https://raw.githubusercontent.com/truongthuanr/self-project/main/dataset/sss/test.csv"
df1 = pd.read_csv(train_url)

# %%
df1.head()
# Out:
#      id  ...  extra_feature
# 0  4705  ...             []
# 1  4706  ...             []
# 2  4707  ...             []
# 3  4708  ...             []
# 4  4709  ...             []
#
# [5 rows x 19 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1505 entries, 0 to 1504
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    1505 non-null   int64
#  1   sku                   1505 non-null   int64
#  2   short_description     1489 non-null   object
#  3   price                 1505 non-null   int64
#  4   discount              1505 non-null   int64
#  5   discount_rate         1505 non-null   int64
#  6   rating_average        1505 non-null   float64
#  7   review_count          1505 non-null   int64
#  8   order_count           1505 non-null   int64
#  9   favourite_count       1505 non-null   int64
#  10  thumbnail_url         1505 non-null   object
#  11  categories            1505 non-null   object
#  12  liked                 1505 non-null   bool
#  13  rating_summary        1505 non-null   object
#  14  brand                 1505 non-null   object
#  15  current_seller        1493 non-null   object
#  16  other_sellers         1505 non-null   object
#  17  configurable_options  1218 non-null   object
#  18  extra_feature         1505 non-null   object
# dtypes: bool(1), float64(1), int64(8), object(9)
# memory usage: 213.2+ KB

# %%
def load_testset(images_url):
  # images,  targets = list(), list()
  images = []
  for i in range(0,len(images_url)):
    # load_img
    img = Image.open(urlopen(images_url[i]))
    img = img.convert("RGB")
    # turn image in to array
    img = asarray(img)

    images.append(img)

  X_test = asarray(images, dtype="uint8")
  return X_test

# %%
data_test = load_testset(df1.thumbnail_url)

# %%
np.savez_compressed("/content/drive/MyDrive/01_AI_ML/sss/test_data_convrgb.npz", data_test)

# %%
data = np.load("/content/drive/MyDrive/01_AI_ML/sss/test_data_convrgb.npz")
test_data = data["arr_0"]
print(f"Loaded: {test_data.shape}")
# Out:
# Loaded: (1505, 280, 280, 3)

# %%
predictions = model.predict(test_data)

# %%
predictions.shape
# Out:
# (1505, 20)

# %%
def prediction_to_tags(inv_label_map, prediction):
  # round the prob
  values = prediction.round()
  # Collect tags
  tags = [inv_label_map[i] for i in range(len(values)) if values[i]==1.0]
  return tags

# %%
prediction_tags = [prediction_to_tags(inv_label_map, prediction) for prediction in predictions]

# %%
prediction_tags
prediction_tags = [" ".join(prediction) for prediction in prediction_tags]

# %%
# plot random 9 image
fig = plt.figure(figsize=(20,10))
for i in range(0,9):
  ax = plt.subplot(3,3,i+1)
  _i = randint(0,len(test_data))
  ax = plt.imshow(test_data[_i])
  plt.title(f"{_i} - {prediction_tags[_i]}")
  plt.axis("off")

# %%
submission = pd.DataFrame({"id":[i+4705 for i in range(len(test_data))],
                           "cloth_type": prediction_tags})

# %%
submission.head(20)
# Out:
#       id                               cloth_type
# 0   4705                   top_t-shirt_sweatshirt
# 1   4706                                    dress
# 2   4707                   top_t-shirt_sweatshirt
# 3   4708                               pants shoe
# 4   4709
# 5   4710                   top_t-shirt_sweatshirt
# 6   4711  top_t-shirt_sweatshirt dress bag_wallet
# 7   4712
# 8   4713
# 9   4714                                     shoe
# 10  4715                   top_t-shirt_sweatshirt
# 11  4716                   top_t-shirt_sweatshirt
# 12  4717                   top_t-shirt_sweatshirt
# 13  4718
# 14  4719                   top_t-shirt_sweatshirt
# 15  4720                                    pants
# 16  4721                   top_t-shirt_sweatshirt
# 17  4722                                    dress
# 18  4723                                    dress
# 19  4724                   top_t-shirt_sweatshirt

# %%
submission.to_csv('/content/drive/MyDrive/01_AI_ML/sss/v1_dropout_dropna.csv', index=False)

# %%
submission.cloth_type.isna().sum()
# Out:
# 0
