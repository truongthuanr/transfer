# %% [markdown]
# <a href="https://colab.research.google.com/github/truongthuanr/transfer/blob/main/08_SSSMarket_truongthuan_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from collections import Counter
import seaborn as sns

from random import randint
from urllib.request import urlopen

from numpy import asarray

# %%
train_url = "https://raw.githubusercontent.com/truongthuanr/self-project/main/dataset/sss/train.csv"
df = pd.read_csv(train_url)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4705 entries, 0 to 4704
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    4705 non-null   int64
#  1   sku                   4705 non-null   int64
#  2   short_description     4640 non-null   object
#  3   price                 4705 non-null   int64
#  4   discount              4705 non-null   int64
#  5   discount_rate         4705 non-null   int64
#  6   rating_average        4705 non-null   float64
#  7   review_count          4705 non-null   int64
#  8   order_count           4705 non-null   int64
#  9   favourite_count       4705 non-null   int64
#  10  thumbnail_url         4705 non-null   object
#  11  categories            4705 non-null   object
#  12  liked                 4705 non-null   bool
#  13  rating_summary        4705 non-null   object
#  14  brand                 4705 non-null   object
#  15  current_seller        4653 non-null   object
#  16  other_sellers         4705 non-null   object
#  17  configurable_options  4042 non-null   object
#  18  extra_feature         4705 non-null   object
#  19  cloth_type            4427 non-null   object
# dtypes: bool(1), float64(1), int64(8), object(10)
# memory usage: 703.1+ KB

# %%
df.head(3)
# Out:
#    id            sku  ... extra_feature                         cloth_type
# 0   0  4777164499549  ...            []  top_t-shirt_sweatshirt shoe pants
# 1   1  2931572867679  ...            []                            sweater
# 2   2  6427102533481  ...            []      watch shoe shirt_blouse pants
#
# [3 rows x 20 columns]

# %% [markdown]
# # Exploratory Data Analysis

# %%
from random import randint
from urllib.request import urlopen

# %%
# plot random 12 image
fig = plt.figure(figsize=(20,10))
for i in range(0,12):
  ax = plt.subplot(3,4,i+1)
  _i = randint(0,total_images)
  img = Image.open(urlopen(df.thumbnail_url[_i]))
  ax = plt.imshow(img)
  plt.title(f"{_i} - {df.cloth_type[_i]}")
  plt.axis("off")

# %% [markdown]
# ## Check for label

# %%
total_images = df.thumbnail_url.notna().sum()
total_images
# Out:
# 4705

# %%
# create a list of list of labels 
labels = df.cloth_type.str.split(" ").tolist()
labels = [item if type(item) == list else [str(item)] for item in labels]
labels[:5]
# Out:
# [['top_t-shirt_sweatshirt', 'shoe', 'pants'],
#  ['sweater'],
#  ['watch', 'shoe', 'shirt_blouse', 'pants'],
#  ['belt', 'dress', 'bag_wallet', 'shoe'],
#  ['bag_wallet', 'dress', 'shoe']]

# %%
# Count the apperence of label
all_label = [label for sub in labels for label in sub]
labels_count = Counter(all_label)
labels_count
# Out:
# Counter({'': 10,
#          'bag_wallet': 438,
#          'belt': 410,
#          'cardigan': 31,
#          'coat': 152,
#          'dress': 768,
#          'glasses': 119,
#          'hat': 195,
#          'headband_head-covering_hair-accessory': 99,
#          'jacket': 414,
#          'jumpsuit': 25,
#          'nan': 278,
#          'pants': 1616,
#          'scarf': 5,
#          'shirt_blouse': 480,
#          'shoe': 1520,
#          'shorts': 479,
#          'skirt': 750,
#          'sweater': 116,
#          'top_t-shirt_sweatshirt': 2382,
#          'vest': 4,
#          'watch': 463})

# %% [markdown]
# Why is label `''`???
#
# Let's check the no label images!!

# %%
index = []
for i in range(len(labels)):
  valid = True
  for label in labels[i]:
    if label == '': valid = False
  if valid == False: index.append(i)

index
# Out:
# [2233, 3586, 4205, 4560, 4628]

# %%
df[df.cloth_type==" "].index
# Out:
# Int64Index([2233, 3586, 4205, 4560, 4628], dtype='int64')

# %%
# plot the invalid images
fig = plt.figure(figsize=(20,10))
for i in range(len(index)):
  ax = plt.subplot(1,5,i+1)
  img = Image.open(urlopen(df.thumbnail_url[index[i]]))
  ax = plt.imshow(img)
  plt.title(f"{index[i]} - {df.cloth_type[index[i]]} no label")
  plt.axis("off")

# %% [markdown]
# Check the n/a label images

# %%
df_na = df[df['cloth_type'].isna()==True].copy()
df_na.reset_index(inplace=True, drop=True)

# %%
# plot random 24 image
fig = plt.figure(figsize=(20,10))
for i in range(0,24):
  ax = plt.subplot(4,6,i+1)
  _i = randint(0,len(df_na))
  img = Image.open(urlopen(df_na.thumbnail_url[_i]))
  ax = plt.imshow(img)
  plt.title(f"{_i} - {df_na.cloth_type[_i]}")
  plt.axis("off")

# %%
df.cloth_type.isna().sum()
# Out:
# 278

# %% [markdown]
# ## Remove na label

# %%
df.drop(labels=df[df.cloth_type==" "].index, inplace=True)
df.drop(labels=df[df.cloth_type.isna()==True].index, inplace=True)
len(df)
# Out:
# 4422

# %%
total_images = df.thumbnail_url.notna().sum()
total_images
# Out:
# 4422

# %%
# create a list of list of labels 
labels = df.cloth_type.str.split(" ").tolist()
labels = [item if type(item) == list else [str(item)] for item in labels]
labels[:5]
# Out:
# [['top_t-shirt_sweatshirt', 'shoe', 'pants'],
#  ['sweater'],
#  ['watch', 'shoe', 'shirt_blouse', 'pants'],
#  ['belt', 'dress', 'bag_wallet', 'shoe'],
#  ['bag_wallet', 'dress', 'shoe']]

# %%
# Count the apperence of label
all_label = [label for sub in labels for label in sub]
labels_count = Counter(all_label)
labels_count
# Out:
# Counter({'bag_wallet': 438,
#          'belt': 410,
#          'cardigan': 31,
#          'coat': 152,
#          'dress': 768,
#          'glasses': 119,
#          'hat': 195,
#          'headband_head-covering_hair-accessory': 99,
#          'jacket': 414,
#          'jumpsuit': 25,
#          'pants': 1616,
#          'scarf': 5,
#          'shirt_blouse': 480,
#          'shoe': 1520,
#          'shorts': 479,
#          'skirt': 750,
#          'sweater': 116,
#          'top_t-shirt_sweatshirt': 2382,
#          'vest': 4,
#          'watch': 463})

# %%
# 1430

# %% [markdown]
# Create Mapping

# %%
labels_count = Counter(all_label)
# sort by frequency
label_name = [tag for tag,count in labels_count.most_common()]
label_freq = [count for tag,count in labels_count.most_common()]

# %%
label_map = {label_name[i]: i for i in range(0,len(label_name))}
inv_label_map = {i:label_name[i] for i in range(0,len(label_name))}

# %% [markdown]
# Whichs are the tops used label?

# %%
fig = plt.figure(figsize=(10,5))
plt.bar(label_name, label_freq, color="#99C8BC")
plt.title("Label in data")
plt.xticks(rotation=90)
for i, (tag,count) in enumerate(labels_count.most_common()):
  plt.text(i, count, f" {count} ", rotation=90, ha="center", va="bottom", color="black")
plt.ylim(0,3000);

# %% [markdown]
# Create a one hot encoding for one list of tags

# %%
from numpy import asarray

# %%
def one_hot_encoder(tags, mapping):
  # create empty vector
  encoding = np.zeros(len(label_map), dtype="uint")
  # mark 1 for each tag in the vector
  for tag in tags:
    encoding[label_map[tag]] = 1
  return encoding

# %%
img.mode == 'RGB'
# Out:
# True

# %%
def load_dataset(images_url, labels, label_map):
  # images,  targets = list(), list()
  images = []
  targets = []
  for i in range(0,len(images_url)):
    # load_img
    img = Image.open(urlopen(images_url[i]))
    if img.mode != 'RGB': img = img.convert('RGB')

    # turn image in to array
    img = asarray(img)
    tags = labels[i]
    target = one_hot_encoder(tags, label_map)

    images.append(img)
    targets.append(target)

  X = asarray(images, dtype="uint8")
  y = asarray(targets, dtype="uint8")

  return X, y

# %%
import tensorflow as tf
device_name = tf.test.gpu_device_name()
device_name
# Out:
# ''

# %%
X, y = load_dataset(df.thumbnail_url[:1000], labels[:1000], label_map)

# %% [markdown]
# save the array:

# %%
np.savez_compressed("/content/drive/MyDrive/01_Personal/99_temp/sss_data_full_dropnalabel.npz", X, y)

# %%
X.shape
# Out:
# (1000, 280, 280, 3)

# %% [markdown]
# load array:

# %%
data = np.load("/content/drive/MyDrive/01_Personal/99_temp/sss_data_100.npz")
X, y = data["arr_0"], data["arr_1"]
print(f"Loaded: {X.shape} {y.shape}")
# Out:
# Loaded: (1000, 280, 280, 3) (1000, 22)

# %%
# load full data
data = np.load("/content/drive/MyDrive/01_Personal/99_temp/sss_data_full.npz")
X, y = data["arr_0"], data["arr_1"]
print(f"Loaded: {X.shape} {y.shape}")
# Out:
# Loaded: (4700, 280, 280, 3) (4700, 22)

# %% [markdown]
# # How to evaluate model

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=99)

# %%
train_yhat = asarray([np.ones(y_train.shape[1]) for _ in range(y_train.shape[0])])

# %%
from sklearn.metrics import fbeta_score
from sklearn.metrics import f1_score

# %%
fbeta_score(y_train, train_yhat, beta=2, average='samples')
# Out:
# 0.34302553465099156

# %%
f1_score(y_train, train_yhat, average='samples')
# Out:
# 0.1823008566859569

# %%
X_train.shape
# Out:
# (3149, 280, 280, 3)

# %% [markdown]
# # Baseline model

# %%
import sys
from keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D, Dense, Flatten
from tensorflow.keras.optimizers import SGD
from keras.preprocessing.image import ImageDataGenerator
from keras import backend

# %%
def fbeta(y_true, y_pred, beta=1):
  # clip prediction
  y_pred = backend.clip(y_pred,0,1)
  # calculate elements
  tp = backend.sum(backend.round(backend.clip(y_true * y_pred, 0, 1)), axis=1)
  fp = backend.sum(backend.round(backend.clip(y_pred - y_true, 0, 1)), axis=1)
  fn = backend.sum(backend.round(backend.clip(y_true - y_pred, 0, 1)), axis=1)
  # calculate precision
  p = tp / (tp + fp + backend.epsilon())
  # calculate recall
  r = tp / (tp + fn + backend.epsilon())
  # calculate fbeta
  bb = beta**2
  fbeta_score = backend.mean((1+bb)*(p*r)/(bb*p+r+backend.epsilon()))
  return fbeta_score

# %%
fbeta(y_train, train_yhat, beta=2)
# Out:
# <tf.Tensor: shape=(), dtype=float64, numpy=0.3430255059671137>

# %%
def define_model(in_shape=(280,280,3), out_shape=22):
  model = Sequential()
  model.add(Conv2D(32,
                   (3,3), 
                   activation="relu", 
                   kernel_initializer='he_uniform',
                   padding="same",
                   input_shape=in_shape
                   )
  )
  model.add(Conv2D(32,
                   (3,3), 
                   activation="relu", 
                   kernel_initializer='he_uniform',
                   padding="same",
                   input_shape=in_shape
                   )
  )
  model.add(MaxPool2D((2, 2)))
  model.add(Conv2D(64,
                   (3,3), 
                   activation="relu", 
                   kernel_initializer='he_uniform',
                   padding="same",
                   input_shape=in_shape
                   )
  )
  model.add(Conv2D(64,
                   (3,3), 
                   activation="relu", 
                   kernel_initializer='he_uniform',
                   padding="same",
                   input_shape=in_shape
                   )
  )
  model.add(MaxPool2D((2, 2)))
  model.add(Conv2D(128,
                   (3,3), 
                   activation="relu", 
                   kernel_initializer='he_uniform',
                   padding="same",
                   input_shape=in_shape
                   )
  )
  model.add(Conv2D(128,
                   (3,3), 
                   activation="relu", 
                   kernel_initializer='he_uniform',
                   padding="same",
                   input_shape=in_shape
                   )
  )
  model.add(MaxPool2D((2, 2)))
  model.add(Flatten())
  model.add(Dense(128, activation="relu", kernel_initializer='he_uniform'))
  model.add(Dense(out_shape, activation="sigmoid"))

  # Compile model
  opt = SGD(learning_rate=0.01, momentum=0.9)
  model.compile(optimizer=opt, loss='binary_crossentropy', metrics=[fbeta])

  return model

# %%
# plot diagnostic learning curves
def summarize_diagnostics(history):
  # plot loss
  plt.subplot(211)
  plt.title("Cross Entropy Loss")
  plt.plot(history.history["loss"], color='blue', label='train')
  plt.plot(history.history['val_loss'],color='orange', label='test')

  # plot accuracy
  plt.subplot(212)
  plt.title("F1 Score")
  plt.plot(history.history["fbeta"], color='blue', label='train')
  plt.plot(history.history['val_fbeta'],color='orange', label='test')

# %%
datagen = ImageDataGenerator(rescale=1.0/225.0)
train_it = datagen.flow(X_train, y_train, batch_size=128)
test_it = datagen.flow(X_test, y_test, batch_size=128)
model = define_model()

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 280, 280, 32)      896
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 280, 280, 32)      9248
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 140, 140, 32)      0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 140, 140, 64)      18496
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 140, 140, 64)      36928
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 70, 70, 64)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 70, 70, 128)       73856
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 70, 70, 128)       147584
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 35, 35, 128)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 156800)            0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               20070528
# _________________________________________________________________
# dense_3 (Dense)              (None, 22)                2838
# =================================================================
# Total params: 20,360,374
# Trainable params: 20,360,374
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(train_it, 
                    steps_per_epoch=len(train_it), 
                    validation_data=test_it, 
                    validation_steps=len(test_it),
                    epochs=50)
# Out:
# Epoch 1/50
# 25/25 [==============================] - 107s 2s/step - loss: 0.3052 - fbeta: 0.1947 - val_loss: 0.2610 - val_fbeta: 0.0765
# Epoch 2/50
# 25/25 [==============================] - 43s 2s/step - loss: 0.2556 - fbeta: 0.1848 - val_loss: 0.2558 - val_fbeta: 0.3167
# Epoch 3/50
# 25/25 [==============================] - 43s 2s/step - loss: 0.2490 - fbeta: 0.2425 - val_loss: 0.2486 - val_fbeta: 0.2434
# Epoch 4/50
# 25/25 [==============================] - 43s 2s/step - loss: 0.2398 - fbeta: 0.2832 - val_loss: 0.2395 - val_fbeta: 0.3448
# Epoch 5/50
# 25/25 [==============================] - 43s 2s/step - loss: 0.2318 - fbeta: 0.3327 - val_loss: 0.2366 - val_fbeta: 0.3902
# Epoch 6/50
# 25/25 [==============================] - 43s 2s/step - loss: 0.2251 - fbeta: 0.3717 - val_loss: 0.2300 - val_fbeta: 0.2579
# Epoch 7/50
# 25/25 [==============================] - 43s 2s/step - loss: 0.2193 - fbeta: 0.3545 - val_loss: 0.2265 - val_fbeta: 0.3887
# Epoch 8/50
# 25/25 [==============================] - 48s 2s/step - loss: 0.2122 - fbeta: 0.4131 - val_loss: 0.2231 - val_fbeta: 0.4089
# Epoch 9/50
# 25/25 [==============================] - 44s 2s/step - loss: 0.2071 - fbeta: 0.4201 - val_loss: 0.2254 - val_fbeta: 0.3024
# Epoch 10/50
# 25/25 [==============================] - 44s 2s/step - loss: 0.2041 - fbeta: 0.4191 - val_loss: 0.2222 - val_fbeta: 0.4230
# Epoch 11/50
# 25/25 [==============================] - 43s 2s/step - loss: 0.1962 - fbeta: 0.4428 - val_loss: 0.2225 - val_fbeta: 0.4332
# Epoch 12/50
# 25/25 [==============================] - 44s 2s/step - loss: 0.1900 - fbeta: 0.4617 - val_loss: 0.2209 - val_fbeta: 0.4568
# Epoch 13/50
# 25/25 [==============================] - 44s 2s/step - loss: 0.1824 - fbeta: 0.4944 - val_loss: 0.2203 - val_fbeta: 0.3267
# Epoch 14/50
# 25/25 [==============================] - 44s 2s/step - loss: 0.1745 - fbeta: 0.5155 - val_loss: 0.2232 - val_fbeta: 0.4079
# Epoch 15/50
# 25/25 [==============================] - 44s 2s/step - loss: 0.1658 - fbeta: 0.5366 - val_loss: 0.2294 - val_fbeta: 0.3885
# Epoch 16/50
# 25/25 [==============================] - 44s 2s/step - loss: 0.1594 - fbeta: 0.5652 - val_loss: 0.2338 - val_fbeta: 0.4776
# Epoch 17/50
# 25/25 [==============================] - 44s 2s/step - loss: 0.1490 - fbeta: 0.5959 - val_loss: 0.2368 - val_fbeta: 0.3731
# Epoch 18/50
# 25/25 [==============================] - 44s 2s/step - loss: 0.1373 - fbeta: 0.6344 - val_loss: 0.2377 - val_fbeta: 0.4668
# Epoch 19/50
# 25/25 [==============================] - 44s 2s/step - loss: 0.1282 - fbeta: 0.6563 - val_loss: 0.2422 - val_fbeta: 0.4433
# Epoch 20/50
# 25/25 [==============================] - 44s 2s/step - loss: 0.1128 - fbeta: 0.7004 - val_loss: 0.2528 - val_fbeta: 0.4465
# Epoch 21/50
# 25/25 [==============================] - 44s 2s/step - loss: 0.0971 - fbeta: 0.7440 - val_loss: 0.2709 - val_fbeta: 0.4360
# Epoch 22/50
# 25/25 [==============================] - 44s 2s/step - loss: 0.0905 - fbeta: 0.7585 - val_loss: 0.2817 - val_fbeta: 0.4459
# Epoch 23/50
# 25/25 [==============================] - 44s 2s/step - loss: 0.0804 - fbeta: 0.7982 - val_loss: 0.3035 - val_fbeta: 0.3694
# Epoch 24/50
# 25/25 [==============================] - 44s 2s/step - loss: 0.0807 - fbeta: 0.7952 - val_loss: 0.3099 - val_fbeta: 0.4035
# Epoch 25/50
# 25/25 [==============================] - 44s 2s/step - loss: 0.0608 - fbeta: 0.8493 - val_loss: 0.3214 - val_fbeta: 0.4572
# Epoch 26/50
# 25/25 [==============================] - 44s 2s/step - loss: 0.0422 - fbeta: 0.9043 - val_loss: 0.3682 - val_fbeta: 0.4935
# Epoch 27/50
# 25/25 [==============================] - 44s 2s/step - loss: 0.0366 - fbeta: 0.9186 - val_loss: 0.3711 - val_fbeta: 0.4583
# Epoch 28/50
# 25/25 [==============================] - 44s 2s/step - loss: 0.0366 - fbeta: 0.9207 - val_loss: 0.3683 - val_fbeta: 0.5016
# Epoch 29/50
# 25/25 [==============================] - 44s 2s/step - loss: 0.0287 - fbeta: 0.9443 - val_loss: 0.3989 - val_fbeta: 0.4486
# Epoch 30/50
# 25/25 [==============================] - 44s 2s/step - loss: 0.0193 - fbeta: 0.9632 - val_loss: 0.4500 - val_fbeta: 0.4573
# Epoch 31/50
# 25/25 [==============================] - 44s 2s/step - loss: 0.0120 - fbeta: 0.9823 - val_loss: 0.4917 - val_fbeta: 0.4516
# Epoch 32/50
# 25/25 [==============================] - 44s 2s/step - loss: 0.0087 - fbeta: 0.9875 - val_loss: 0.5049 - val_fbeta: 0.4897
# Epoch 33/50
# 25/25 [==============================] - 44s 2s/step - loss: 0.0055 - fbeta: 0.9927 - val_loss: 0.5301 - val_fbeta: 0.4490
# Epoch 34/50
# 25/25 [==============================] - 44s 2s/step - loss: 0.0043 - fbeta: 0.9940 - val_loss: 0.5760 - val_fbeta: 0.4702
# Epoch 35/50
# 25/25 [==============================] - 44s 2s/step - loss: 0.0039 - fbeta: 0.9942 - val_loss: 0.5743 - val_fbeta: 0.4775
# Epoch 36/50
# 25/25 [==============================] - 44s 2s/step - loss: 0.0035 - fbeta: 0.9944 - val_loss: 0.6143 - val_fbeta: 0.4642
# Epoch 37/50
# 25/25 [==============================] - 44s 2s/step - loss: 0.0029 - fbeta: 0.9965 - val_loss: 0.6245 - val_fbeta: 0.4791
# Epoch 38/50
# 25/25 [==============================] - 44s 2s/step - loss: 0.0025 - fbeta: 0.9968 - val_loss: 0.6429 - val_fbeta: 0.4579
# Epoch 39/50
# 25/25 [==============================] - 44s 2s/step - loss: 0.0022 - fbeta: 0.9970 - val_loss: 0.6498 - val_fbeta: 0.4664
# Epoch 40/50
# 25/25 [==============================] - 44s 2s/step - loss: 0.0021 - fbeta: 0.9966 - val_loss: 0.6659 - val_fbeta: 0.4637
# Epoch 41/50
# 25/25 [==============================] - 44s 2s/step - loss: 0.0019 - fbeta: 0.9968 - val_loss: 0.6833 - val_fbeta: 0.4669
# Epoch 42/50
# 25/25 [==============================] - 44s 2s/step - loss: 0.0018 - fbeta: 0.9979 - val_loss: 0.6851 - val_fbeta: 0.4697
# Epoch 43/50
# 25/25 [==============================] - 44s 2s/step - loss: 0.0018 - fbeta: 0.9971 - val_loss: 0.6909 - val_fbeta: 0.4593
# Epoch 44/50
# 25/25 [==============================] - 44s 2s/step - loss: 0.0025 - fbeta: 0.9962 - val_loss: 0.7022 - val_fbeta: 0.4932
# Epoch 45/50
# 25/25 [==============================] - 44s 2s/step - loss: 0.0018 - fbeta: 0.9983 - val_loss: 0.6918 - val_fbeta: 0.4801
# Epoch 46/50
# 25/25 [==============================] - 44s 2s/step - loss: 0.0018 - fbeta: 0.9980 - val_loss: 0.7020 - val_fbeta: 0.4672
# Epoch 47/50
# 25/25 [==============================] - 44s 2s/step - loss: 0.0028 - fbeta: 0.9965 - val_loss: 0.6989 - val_fbeta: 0.4646
# Epoch 48/50
# 25/25 [==============================] - 44s 2s/step - loss: 0.0018 - fbeta: 0.9979 - val_loss: 0.7237 - val_fbeta: 0.4684
# Epoch 49/50
# 25/25 [==============================] - 44s 2s/step - loss: 0.0018 - fbeta: 0.9975 - val_loss: 0.7171 - val_fbeta: 0.4559
# Epoch 50/50
# 25/25 [==============================] - 44s 2s/step - loss: 0.0017 - fbeta: 0.9974 - val_loss: 0.7188 - val_fbeta: 0.4707

# %%
loss, fbeta = model.evaluate(test_it, steps=len(test_it))
# Out:
# 13/13 [==============================] - 6s 406ms/step - loss: 0.7188 - fbeta: 0.4653

# %%
print(f"> loss = {loss:.3f}, f1-mean = {fbeta:.3f}")
# Out:
# > loss = 0.719, f1-mean = 0.465

# %%
summarize_diagnostics(history)

# %%
model.save_weights('/content/drive/MyDrive/01_Personal/99_temp/sss_models/firstweight/firstweight')

# %%
model.load_weights('/content/drive/MyDrive/01_Personal/99_temp/sss_models/firstweight/firstweight')

# %% [markdown]
# # Prediction

# %%
train_url = "https://raw.githubusercontent.com/truongthuanr/self-project/main/dataset/sss/test.csv"
df1 = pd.read_csv(train_url)

# %%
df1.head()
# Out:
#      id  ...  extra_feature
# 0  4705  ...             []
# 1  4706  ...             []
# 2  4707  ...             []
# 3  4708  ...             []
# 4  4709  ...             []
#
# [5 rows x 19 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1505 entries, 0 to 1504
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    1505 non-null   int64
#  1   sku                   1505 non-null   int64
#  2   short_description     1489 non-null   object
#  3   price                 1505 non-null   int64
#  4   discount              1505 non-null   int64
#  5   discount_rate         1505 non-null   int64
#  6   rating_average        1505 non-null   float64
#  7   review_count          1505 non-null   int64
#  8   order_count           1505 non-null   int64
#  9   favourite_count       1505 non-null   int64
#  10  thumbnail_url         1505 non-null   object
#  11  categories            1505 non-null   object
#  12  liked                 1505 non-null   bool
#  13  rating_summary        1505 non-null   object
#  14  brand                 1505 non-null   object
#  15  current_seller        1493 non-null   object
#  16  other_sellers         1505 non-null   object
#  17  configurable_options  1218 non-null   object
#  18  extra_feature         1505 non-null   object
# dtypes: bool(1), float64(1), int64(8), object(9)
# memory usage: 213.2+ KB

# %%
def load_testset(images_url):
  # images,  targets = list(), list()
  images = []
  for i in range(0,len(images_url)):
    # load_img
    img = Image.open(urlopen(images_url[i]))
    img.convert("RGB")
    # turn image in to array
    img = asarray(img)[:,:,:3]

    images.append(img)

  X_test = asarray(images, dtype="uint8")
  return X_test

# %%
data_test = load_testset(df1.thumbnail_url)

# %%
np.savez_compressed("/content/drive/MyDrive/01_Personal/99_temp/test_data.npz", data_test)

# %%
# model = tf.keras.models.load_model('/content/drive/MyDrive/01_Personal/99_temp/sss_models/first.h5')

# %%
data = np.load("/content/drive/MyDrive/01_Personal/99_temp/test_data.npz")
test_data = data["arr_0"]
print(f"Loaded: {test_data.shape}")
# Out:
# Loaded: (1505, 280, 280, 3)

# %%
predictions = model.predict(test_data)

# %%
predictions.shape
# Out:
# (1505, 22)

# %%
def prediction_to_tags(inv_label_map, prediction):
  # round the prob
  values = prediction.round()
  # Collect tags
  tags = [inv_label_map[i] for i in range(len(values)) if values[i]==1.0]
  return tags

# %%
prediction_tags = [prediction_to_tags(inv_label_map, prediction) for prediction in predictions]

# %%
prediction_tags
prediction_tags = [" ".join(prediction) for prediction in prediction_tags]

# %%
# plot random 9 image
fig = plt.figure(figsize=(20,10))
for i in range(0,9):
  ax = plt.subplot(3,3,i+1)
  _i = randint(0,len(test_data))
  ax = plt.imshow(test_data[_i])
  plt.title(f"{_i} - {prediction_tags[_i]}")
  plt.axis("off")

# %%
submission = pd.DataFrame({"id":[i+4705 for i in range(len(test_data))],
                           "cloth_type": prediction_tags})

# %%
submission.head(20)
# Out:
#       id                                      cloth_type
# 0   4705                          top_t-shirt_sweatshirt
# 1   4706                top_t-shirt_sweatshirt shoe coat
# 2   4707                          top_t-shirt_sweatshirt
# 3   4708  pants shoe shirt_blouse bag_wallet jacket belt
# 4   4709
# 5   4710                                           dress
# 6   4711                          top_t-shirt_sweatshirt
# 7   4712
# 8   4713                   top_t-shirt_sweatshirt jacket
# 9   4714               top_t-shirt_sweatshirt pants shoe
# 10  4715                    top_t-shirt_sweatshirt skirt
# 11  4716                                             nan
# 12  4717                     top_t-shirt_sweatshirt shoe
# 13  4718
# 14  4719                          top_t-shirt_sweatshirt
# 15  4720       top_t-shirt_sweatshirt pants shirt_blouse
# 16  4721                                      shorts nan
# 17  4722                    top_t-shirt_sweatshirt dress
# 18  4723                    top_t-shirt_sweatshirt dress
# 19  4724

# %%
submission.to_csv('/content/drive/MyDrive/01_Personal/99_temp/sss_submission/01_first.csv', index=False)
